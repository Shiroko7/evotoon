# %%
## IMPORTS 
import time
import evotoon
from data_classes import CatParam, IntParam, FloatParam

from scipy.stats import friedmanchisquare
import scikit_posthocs as sp

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns#

import random

import warnings
warnings.filterwarnings("ignore")

## MAKE SEED
SEED = evotoon.make_seed(925)

# %%
folder_list = [
		'./InstanciasNKLandscapes/Instances-Testing/nk_2_20',
		'./InstanciasNKLandscapes/Instances-Testing/nk_2_38',
		'./InstanciasNKLandscapes/Instances-Testing/nk_2_52',
		'./InstanciasNKLandscapes/Instances-Testing/nk_3_20',
		'./InstanciasNKLandscapes/Instances-Testing/nk_3_34',
		'./InstanciasNKLandscapes/Instances-Testing/nk_3_48',
		'./InstanciasNKLandscapes/Instances-Testing/nk_4_20',
		'./InstanciasNKLandscapes/Instances-Testing/nk_4_30',
		'./InstanciasNKLandscapes/Instances-Testing/nk_4_40',
		'./InstanciasNKLandscapes/Instances-Testing/nk_5_20',
		'./InstanciasNKLandscapes/Instances-Testing/nk_5_28',
		'./InstanciasNKLandscapes/Instances-Testing/nk_5_38',
		'./InstanciasNKLandscapes/Instances-Testing/nk_6_20',
		'./InstanciasNKLandscapes/Instances-Testing/nk_6_26',
		'./InstanciasNKLandscapes/Instances-Testing/nk_6_32'
 ]

# %%
separator = "--------------------------------------------------------"
## EXAMPLE WITH CodGA

# Env configuration
population_size = 15

# Parameter settings
float_params = [
	FloatParam("p_c", 0.001, 1, 3),
	FloatParam("p_m", 0.001, 1, 3),
]
cat_params = [
	CatParam("c_0", [1,2])
]
int_params = [
	IntParam("N", 1, 50),
]

all_params = float_params + int_params + cat_params
all_params = {param.name: param for param in all_params}



initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)

# Tuner parameters

update_cycle = 3
budget = 1000

# SET ENVIRONMENT FOR THE ACO ALGORITHM TO TUNE
n = 100

instance_list = [
	"./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1",
	"./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2",
	"./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3",
	"./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4",
	"./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5",
	"./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1",
	"./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.2",
	"./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.3",
	"./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.4",
	"./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.5",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.1",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.2",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.3",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.4",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5",
	"./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5",
]

instance_list, seed_list = evotoon.select_seeds(instance_list, n, SEED)

print(separator, "Instances running and seeds", separator)
for ins,seed in zip(instance_list,seed_list):
	print("instance:", ins, "seed:", seed)

function_kwargs = {
	"executable_path": "./CodGA/ga-nk",
	"instance_list": instance_list,
	"seed_list": seed_list,
	"output": "xd.txt",
	"t_max": 1000 
}

model_kwargs = {
	"layers": 2,
	"neurons": 2 * [4]
}
# Out:
# -------------------------------------------------------- Instances running and seeds --------------------------------------------------------
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.1 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.2 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.3 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.4 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_4_30/nk_30_4.5 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_2_52/nk_52_2.1 seed: 1006
# ...
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1024
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 925
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 926
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 927
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 928
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 929
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 930
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 931
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 932
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 933
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 934
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 935
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 936
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 937
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 938
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 939
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 940
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 941
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 942
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 943
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 944
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 945
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 946
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 947
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 948
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 949
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 950
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 951
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 952
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 953
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 954
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 955
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 956
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 957
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 958
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 959
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 960
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 961
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 962
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 963
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 964
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 965
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 966
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 967
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 968
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 969
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 970
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 971
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 972
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 973
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 974
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 975
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 976
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 977
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 978
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 979
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 980
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 981
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 982
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 983
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 984
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 985
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 986
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 987
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 988
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 989
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 990
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 991
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 992
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 993
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 994
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 995
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 996
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 997
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 998
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 999
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1000
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1001
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1002
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1003
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1004
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1005
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1006
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1007
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1008
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1009
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1010
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1011
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1012
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1013
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1014
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1015
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1016
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1017
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1018
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1019
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1020
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1021
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1022
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1023
# instance: ./InstanciasNKLandscapes/Instances-Training/nk_6_20/nk_20_6.5 seed: 1024

# %%
import time
for i in range(2,31,4):
	population_size = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./codga_population_exp/population_size_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-810e9d259f41> in <module>
#       4         start = time.time()
#       5         initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
# ----> 6         df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
#       7         end = time.time()
#       8         df.to_csv(f'./codga_population_exp/population_size_{i}_{round(end-start)}.txt', sep='\t', index=False)
#
# TypeError: evo_tunning() missing 3 required positional arguments: 'update_cycle', 'hc_max_tries', and 'hc_p_worse'

# %%
population_size = 15
for i in range(1,10):
	update_cycle = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, update_cycle=update_cycle, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./codga_population_exp/update_cycle_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x168f18d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x168cb98b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25

# %%
population_size = 15
update_cycle = 1
hc_max_tries = 5
for i in range(0,11):
	hc_p_worse = i/10
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./codga_hc_p_worse_exp/hc_p_worse_{i/10}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x165649160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x164d74dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25

# %%
population_size = 15
update_cycle = 1
hc_p_worse = 0.25
for i in range(20,21):
	hc_max_tries = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./codga_hc_max_tries_exp/hc_max_tries_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25

# %%
# n_seeds
population_size = 15
update_cycle = 1
hc_p_worse = 0.25
hc_max_tries = 5
for i in range(1,10):
	n_seeds = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, n_seeds=n_seeds, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./codga_nseeds_exp/nseeds_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 985
# Budget left 985
# Budget left 910
# Budget left 835
# Budget left 760
# Budget left 685
# Budget left 610
# Budget left 535
# Budget left 460
# Budget left 385
# Budget left 310
# Budget left 235
# Budget left 160
# Budget left 85
# Budget left 10
# Total Budget: 970
# Budget left 970
# Budget left 895
# Budget left 820
# Budget left 745
# Budget left 670
# Budget left 595
# Budget left 520
# Budget left 445
# Budget left 370
# Budget left 295
# Budget left 220
# Budget left 145
# Budget left 70
# Total Budget: 955
# Budget left 955
# Budget left 880
# Budget left 805
# Budget left 730
# Budget left 655
# Budget left 580
# Budget left 505
# Budget left 430
# Budget left 355
# Budget left 280
# Budget left 205
# Budget left 130
# Budget left 55
# Total Budget: 940
# Budget left 940
# Budget left 865
# Budget left 790
# Budget left 715
# Budget left 640
# Budget left 565
# Budget left 490
# Budget left 415
# Budget left 340
# Budget left 265
# Budget left 190
# Budget left 115
# Budget left 40
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x15ceea0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 925
# Budget left 925
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x15d09daf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 910
# Budget left 910
# Budget left 835
# Budget left 760
# Budget left 685
# Budget left 610
# Budget left 535
# Budget left 460
# Budget left 385
# Budget left 310
# Budget left 235
# Budget left 160
# Budget left 85
# Budget left 10
# Total Budget: 895
# Budget left 895
# Budget left 820
# Budget left 745
# Budget left 670
# Budget left 595
# Budget left 520
# Budget left 445
# Budget left 370
# Budget left 295
# Budget left 220
# Budget left 145
# Budget left 70
# Total Budget: 880
# Budget left 880
# Budget left 805
# Budget left 730
# Budget left 655
# Budget left 580
# Budget left 505
# Budget left 430
# Budget left 355
# Budget left 280
# Budget left 205
# Budget left 130
# Budget left 55
# Total Budget: 865
# Budget left 865
# Budget left 790
# Budget left 715
# Budget left 640
# Budget left 565
# Budget left 490
# Budget left 415
# Budget left 340
# Budget left 265
# Budget left 190
# Budget left 115
# Budget left 40

# %%
# n_seeds
population_size = 15
update_cycle = 1
hc_p_worse = 0.25
hc_max_tries = 5

n_seeds = 9
start = time.time()
initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, n_seeds=n_seeds, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
end = time.time()
df.to_csv(f'./codga_nseeds_exp/nseeds_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 850
# Budget left 850
# Budget left 775
# Budget left 700
# Budget left 625
# Budget left 550
# Budget left 475
# Budget left 400
# Budget left 325
# Budget left 250
# Budget left 175
# Budget left 100
# Budget left 25
