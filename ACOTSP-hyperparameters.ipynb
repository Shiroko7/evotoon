# %%
## IMPORTS 
import time

import evotoon
from data_classes import CatParam, IntParam, FloatParam

from scipy.stats import friedmanchisquare
import scikit_posthocs as sp

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns#

import random
import warnings
warnings.filterwarnings("ignore")

## MAKE SEED
SEED = evotoon.make_seed(465)

# %%
optimal_solutions = {
	"a280" : 2579,
	"ali535" : 202339,
	"att48" : 10628,
	"att532" : 27686,
	"bayg29" : 1610,
	"bays29" : 2020,
	"berlin52" : 7542,
	"bier127" : 118282,
	"brazil58" : 25395,
	"brd14051" : 469385,
	"brg180" : 1950,
	"burma14" : 3323,
	"ch130" : 6110,
	"ch150" : 6528,
	"d198" : 15780,
	"d493" : 35002,
	"d657" : 48912,
	"d1291" : 50801,
	"d1655" : 62128,
	"d2103" : 80450,
	"d15112" : 1573084,
	"d18512" : 645238,
	"dantzig42" : 699,
	"dsj1000" : 18659688, 
	"dsj1000" : 18660188,
	"eil51" : 426,
	"eil76" : 538,
	"eil101" : 629,
	"fl417" : 11861,
	"fl1400" : 20127,
	"fl1577" : 22249,
	"fl3795" : 28772,
	"fnl4461" : 182566,
	"fri26" : 937,
	"gil262" : 2378,
	"gr17" : 2085,
	"gr21" : 2707,
	"gr24" : 1272,
	"gr48" : 5046,
	"gr96" : 55209,
	"gr120" : 6942,
	"gr137" : 69853,
	"gr202" : 40160,
	"gr229" : 134602,
	"gr431" : 171414,
	"gr666" : 294358,
	"hk48" : 11461,
	"kroA100" : 21282,
	"kroB100" : 22141,
	"kroC100" : 20749,
	"kroD100" : 21294,
	"kroE100" : 22068,
	"kroA150" : 26524,
	"kroB150" : 26130,
	"kroA200" : 29368,
	"kroB200" : 29437,
	"lin105" : 14379,
	"lin318" : 42029,
	"linhp318" : 41345,
	"nrw1379" : 56638,
	"p654" : 34643,
	"pa561" : 2763,
	"pcb442" : 50778,
	"pcb1173" : 56892,
	"pcb3038" : 137694,
	"pla7397" : 23260728,
	"pla33810" : 66048945,
	"pla85900" : 142382641,
	"pr76" : 108159,
	"pr107" : 44303,
	"pr124" : 59030,
	"pr136" : 96772,
	"pr144" : 58537,
	"pr152" : 73682,
	"pr226" : 80369,
	"pr264" : 49135,
	"pr299" : 48191,
	"pr439" : 107217,
	"pr1002" : 259045,
	"pr2392" : 378032,
	"rat99" : 1211,
	"rat195" : 2323,
	"rat575" : 6773,
	"rat783" : 8806,
	"rd100" : 7910,
	"rd400" : 15281,
	"rl1304" : 252948,
	"rl1323" : 270199,
	"rl1889" : 316536,
	"rl5915" : 565530,
	"rl5934" : 556045,
	"rl11849" : 923288,
	"si175" : 21407,
	"si535" : 48450,
	"si1032" : 92650,
	"st70" : 675,
	"swiss42" : 1273,
	"ts225" : 126643,
	"tsp225" : 3916,
	"u159" : 42080,
	"u574" : 36905,
	"u724" : 41910,
	"u1060" : 224094,
	"u1432" : 152970,
	"u1817" : 57201,
	"u2152" : 64253,
	"u2319" : 234256,
	"ulysses16" : 6859,
	"ulysses22" : 7013,
	"usa13509" : 19982859,
	"vm1084" : 239297,
	"vm1748" : 336556,
}

# %%
separator = "--------------------------------------------------------"
## EXAMPLE WITH AntKnapsackClean-Master
population_size=25
# Parameter settings
float_params = [
	FloatParam("alpha", 1.0, 10.0, 3),
	FloatParam("beta", 1.0, 10.0, 3),	
	FloatParam("rho", 0.1, 1.0, 3),
]
int_params = [
	IntParam("ants", 5, 100),
	IntParam("nnls", 5, 50),
	IntParam("elitistants", 1, 750)
]
cat_params = [
	CatParam("localsearch", [0,1,2,3]),
	CatParam("dlb", [0,1])
]
all_params = float_params + int_params + cat_params
all_params = {param.name: param for param in all_params}

initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)

# Tuner parameters

update_cycle = 3
budget = 1000

# SET ENVIRONMENT FOR THE ACO ALGORITHM TO TUNE
#path = "./ALL_tsp"
n = 1
m = 100

#instance_list = evotoon.choose_instances(path, n , SEED)

instance_list = [
 	'./ALL_tsp/ch150.tsp',
	'./ALL_tsp/u724.tsp',
	'./ALL_tsp/rl1323.tsp',
	'./ALL_tsp/st70.tsp',
	'./ALL_tsp/d1655.tsp',
	'./ALL_tsp/u1817.tsp',
	'./ALL_tsp/kroB200.tsp',
	'./ALL_tsp/gr96.tsp',
	'./ALL_tsp/pr226.tsp',
	'./ALL_tsp/gr431.tsp',
	'./ALL_tsp/gr137.tsp',
	'./ALL_tsp/att532.tsp',
	'./ALL_tsp/rd100.tsp',
	'./ALL_tsp/rd400.tsp',
	'./ALL_tsp/pcb1173.tsp',
	'./ALL_tsp/eil76.tsp',
	'./ALL_tsp/pr264.tsp',
	'./ALL_tsp/pr439.tsp',
	'./ALL_tsp/u574.tsp',
	'./ALL_tsp/bier127.tsp',
]

instance_list, seed_list = evotoon.select_seeds(instance_list, m, SEED)
optimal_list = [optimal_solutions[instance[:-4].split("/")[-1]] for instance in instance_list]
# print(separator, "Instances running and seeds", separator)
# for ins, seed, optimal in zip(instance_list,seed_list, optimal_list):
# 	print("instance:", ins, "seed:", seed, "optimal", optimal)


function_kwargs = {
	"executable_path": "./ACOTSP-master/acotsp",
	"instance_list": instance_list,
	"seed_list": seed_list,
	"optimal_list": optimal_list,
}

model_kwargs = {
	"layers": 3,
	"neurons": 3 * [8]
}

# %%
# POPULATION_SIZE
import time


for i in range(2,51,4):
	population_size = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./acotsp_population_exp/population_size_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 990
# Budget left 990
# Budget left 980
# Budget left 970
# Budget left 960
# Budget left 950
# Budget left 940
# Budget left 930
# Budget left 920
# Budget left 910
# Budget left 900
# Budget left 890
# Budget left 880
# Budget left 870
# Budget left 860
# Budget left 850
# Budget left 840
# Budget left 830
# Budget left 820
# Budget left 810
# Budget left 800
# Budget left 790
# Budget left 780
# Budget left 770
# Budget left 760
# Budget left 750
# Budget left 740
# Budget left 730
# Budget left 720
# Budget left 710
# Budget left 700
# Budget left 690
# Budget left 680
# Budget left 670
# Budget left 660
# Budget left 650
# Budget left 640
# Budget left 630
# Budget left 620
# Budget left 610
# Budget left 600
# Budget left 590
# Budget left 580
# Budget left 570
# Budget left 560
# Budget left 550
# Budget left 540
# Budget left 530
# Budget left 520
# Budget left 510
# Budget left 500
# Budget left 490
# Budget left 480
# Budget left 470
# Budget left 460
# Budget left 450
# Budget left 440
# Budget left 430
# Budget left 420
# Budget left 410
# Budget left 400
# Budget left 390
# Budget left 380
# Budget left 370
# Budget left 360
# Budget left 350
# Budget left 340
# Budget left 330
# Budget left 320
# Budget left 310
# Budget left 300
# Budget left 290
# Budget left 280
# Budget left 270
# Budget left 260
# Budget left 250
# Budget left 240
# Budget left 230
# Budget left 220
# Budget left 210
# Budget left 200
# Budget left 190
# Budget left 180
# Budget left 170
# Budget left 160
# Budget left 150
# Budget left 140
# Budget left 130
# Budget left 120
# Budget left 110
# Budget left 100
# Budget left 90
# Budget left 80
# Budget left 70
# Budget left 60
# Budget left 50
# Budget left 40
# Budget left 30
# Budget left 20
# Budget left 10
# Total Budget: 970
# Budget left 970
# Budget left 940
# Budget left 910
# Budget left 880
# Budget left 850
# Budget left 820
# Budget left 790
# Budget left 760
# Budget left 730
# Budget left 700
# Budget left 670
# Budget left 640
# Budget left 610
# Budget left 580
# Budget left 550
# Budget left 520
# Budget left 490
# Budget left 460
# Budget left 430
# Budget left 400
# Budget left 370
# Budget left 340
# Budget left 310
# Budget left 280
# Budget left 250
# Budget left 220
# Budget left 190
# Budget left 160
# Budget left 130
# Budget left 100
# Budget left 70
# Budget left 40
# Budget left 10
# Total Budget: 950
# Budget left 950
# Budget left 900
# Budget left 850
# Budget left 800
# Budget left 750
# Budget left 700
# Budget left 650
# Budget left 600
# Budget left 550
# Budget left 500
# Budget left 450
# Budget left 400
# Budget left 350
# Budget left 300
# Budget left 250
# Budget left 200
# Budget left 150
# Budget left 100
# Budget left 50
# Total Budget: 930
# Budget left 930
# Budget left 860
# Budget left 790
# Budget left 720
# Budget left 650
# Budget left 580
# Budget left 510
# Budget left 440
# Budget left 370
# Budget left 300
# Budget left 230
# Budget left 160
# Budget left 90
# Budget left 20
# Total Budget: 910
# Budget left 910
# Budget left 820
# Budget left 730
# Budget left 640
# Budget left 550
# Budget left 460
# Budget left 370
# Budget left 280
# Budget left 190
# Budget left 100
# Budget left 10
# Total Budget: 890
# Budget left 890
# Budget left 780
# Budget left 670
# Budget left 560
# Budget left 450
# Budget left 340
# Budget left 230
# Budget left 120
# Budget left 10
# Total Budget: 870
# Budget left 870
# Budget left 740
# Budget left 610
# Budget left 480
# Budget left 350
# Budget left 220
# Budget left 90
# Total Budget: 850
# Budget left 850
# Budget left 700
# Budget left 550
# Budget left 400
# Budget left 250
# Budget left 100
# Total Budget: 830
# Budget left 830
# Budget left 660
# Budget left 490
# Budget left 320
# Budget left 150
# Total Budget: 810
# Budget left 810
# Budget left 620
# Budget left 430
# Budget left 240
# Budget left 50
# Total Budget: 790
# Budget left 790
# Budget left 580
# Budget left 370
# Budget left 160
# Total Budget: 770
# Budget left 770
# Budget left 540
# Budget left 310
# Budget left 80
# Total Budget: 750
# Budget left 750
# Budget left 500
# Budget left 250

# %%
# POPULATION_SIZE

population_size = 25
for i in range(1,10):
	update_cycle = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, update_cycle=update_cycle, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./acotsp_population_exp/update_cycle_{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x16b3f7a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x16b3f7ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125

# %%
# HC_P_WORSE
population_size = 25
update_cycle = 1
hc_max_tries = 5
for i in range(0,11):
	hc_p_worse = i/10
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./acotsp_hc_p_worse_exp/hc_p_worse{i/10}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x13e440d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x13e47c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125

# %%
# hc_max_tries
population_size = 25
update_cycle = 1
hc_p_worse = 0.25
for i in range(11,21):
	hc_max_tries = i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./acotsp_hc_max_tries_exp/hc_max_tries{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x16c7e1f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x16c7e1790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125

# %%
# hc_max_tries
population_size = 25
update_cycle = 1
hc_p_worse = 0.25
hc_max_tries = 5
for i in range(1,10):
	n_seeds=i
	start = time.time()
	initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
	df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, n_seeds=n_seeds, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
	end = time.time()
	df.to_csv(f'./acotsp_nseeds_exp/n_seeds{i}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 975
# Budget left 975
# Budget left 850
# Budget left 725
# Budget left 600
# Budget left 475
# Budget left 350
# Budget left 225
# Budget left 100
# Total Budget: 950
# Budget left 950
# Budget left 825
# Budget left 700
# Budget left 575
# Budget left 450
# Budget left 325
# Budget left 200
# Budget left 75
# Total Budget: 925
# Budget left 925
# Budget left 800
# Budget left 675
# Budget left 550
# Budget left 425
# Budget left 300
# Budget left 175
# Budget left 50
# Total Budget: 900
# Budget left 900
# Budget left 775
# Budget left 650
# Budget left 525
# Budget left 400
# Budget left 275
# Budget left 150
# Budget left 25
# WARNING:tensorflow:5 out of the last 5 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x15ecbce50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 875
# Budget left 875
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
# WARNING:tensorflow:6 out of the last 6 calls to <function PreprocessingLayer.make_adapt_function.<locals>.adapt_step at 0x15ec81e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Total Budget: 850
# Budget left 850
# Budget left 725
# Budget left 600
# Budget left 475
# Budget left 350
# Budget left 225
# Budget left 100
# Total Budget: 825
# Budget left 825
# Budget left 700
# Budget left 575
# Budget left 450
# Budget left 325
# Budget left 200
# Budget left 75
# Total Budget: 800
# Budget left 800
# Budget left 675
# Budget left 550
# Budget left 425
# Budget left 300
# Budget left 175
# Budget left 50
# Total Budget: 775
# Budget left 775
# Budget left 650
# Budget left 525
# Budget left 400
# Budget left 275
# Budget left 150
# Budget left 25

# %%
# hc_max_tries
population_size = 25
update_cycle = 1
hc_p_worse = 0.25
hc_max_tries = 5

n_seeds=10
start = time.time()
initial_batch = evotoon.initialization(population_size, float_params, int_params, cat_params)
df = evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, population_size=population_size, update_cycle=update_cycle, hc_max_tries=hc_max_tries, hc_p_worse=hc_p_worse, n_seeds=n_seeds, initial_batch=initial_batch, execute_algorithm=evotoon.execute_ACOTSP, model_kwargs=model_kwargs, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
end = time.time()
df.to_csv(f'./acotsp_nseeds_exp/n_seeds{10}_{round(end-start)}.txt', sep='\t', index=False)
# Out:
# Total Budget: 750
# Budget left 750
# Budget left 625
# Budget left 500
# Budget left 375
# Budget left 250
# Budget left 125
