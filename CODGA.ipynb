# %%
## IMPORTS 
import evotoon
from data_classes import CatParam, IntParam, FloatParam


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns#

import random

# %%
## MAKE SEED
SEED = evotoon.make_seed(283)
separator = "--------------------------------------------------------"

# %%
## EXAMPLE WITH CodGA

# Env configuration
poblation_size = 10

# Parameter settings
float_params = [
	FloatParam("p_c", 0.0001, 0.1, 4),
	FloatParam("p_m", 0.0001, 0.1, 4),
]
int_params = [
	IntParam("N", 1, 100),
	IntParam("t_max", 1, 1000),
]
cat_params = [
	CatParam("c_0", [1, 2]),
]

all_params = float_params + int_params + cat_params
all_params = {param.name: param for param in all_params}

initial_batch = evotoon.initialization(poblation_size, float_params, int_params, cat_params)

# Tuner parameters

update_cycle = 5
budget = 30

# SET ENVIRONMENT FOR THE ACO ALGORITHM TO TUNE
instance_list = [
	"./CodGA/nk_38-3.22",
]
seed_list = [SEED + i for i in range(len(instance_list))]
print(separator, "Instances running and seeds", separator)
for ins,seed in zip(instance_list,seed_list):
	print("instance:", ins, "seed:", seed)

function_kwargs = {
	"executable_path": "./CodGA/ga-nk",
	"instance_list": instance_list,
	"seed_list": seed_list,
	"output": "xd.txt"
}

print(pd.DataFrame(initial_batch))
# Out:
# -------------------------------------------------------- Instances running and seeds --------------------------------------------------------
# instance: ./AntKnapsackClean-master/instances/weing1.txt seed: 283
# instance: ./AntKnapsackClean-master/instances/weing2.txt seed: 284
# instance: ./AntKnapsackClean-master/instances/weing3.txt seed: 285
# instance: ./AntKnapsackClean-master/instances/weing4.txt seed: 286
# instance: ./AntKnapsackClean-master/instances/weing7.txt seed: 287
#       p_c     p_m   N  t_max  c_0
# 0  0.0359  0.0226  99    931    1
# 1  0.0003  0.0461  41    470    1
# 2  0.0970  0.0663  24    552    2
# 3  0.0280  0.0136  54     41    1
# 4  0.0795  0.0922  31    103    1
# 5  0.0670  0.0041  69    709    2
# 6  0.0482  0.0312  88    392    2
# 7  0.0502  0.0703   4    622    2
# 8  0.0856  0.0522  70    801    2
# 9  0.0120  0.0820  16    204    1

# %%
evotoon.execute_CodGA("./CodGA/nk_38-3.22", "xd.txt", 123, "./CodGA/ga-nk", 0, 0, 10, 100, 1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7256/2021149368.py in <module>
# ----> 1 evotoon.execute_CodGA("./CodGA/nk_38-3.22", "xd.txt", 123, "./CodGA/ga-nk", 0, 0, 10, 100, 1)
#
# c:\Users\thoth\Documents\evotoon\evotoon.py in execute_CodGA(instance, output, seed, executable_path, p_c, p_m, N, t_max, c_0)
#     182     """
#     183     cmd = [executable_path, instance, output, str(p_c), str(p_m), str(N), str(t_max), str(seed), str(c_0)]
# --> 184     result = subprocess.run(cmd, stdout=subprocess.PIPE)
#     185     output = float(result.stdout.decode("utf-8"))
#     186     return output * -1
#
# C:\Program Files\Python37\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     464         kwargs['stderr'] = PIPE
#     465
# --> 466     with Popen(*popenargs, **kwargs) as process:
#     467         try:
#     468             stdout, stderr = process.communicate(input, timeout=timeout)
#
# C:\Program Files\Python37\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     767                                 c2pread, c2pwrite,
#     768                                 errread, errwrite,
# --> 769                                 restore_signals, start_new_session)
#     770         except:
#     771             # Cleanup if the child failed starting.
#
# C:\Program Files\Python37\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1170                                          env,
#    1171                                          os.fspath(cwd) if cwd is not None else None,
# -> 1172                                          startupinfo)
#    1173             finally:
#    1174                 # Child is launched. Close the parent's copy of those pipe
#
# OSError: [WinError 193] %1 no es una aplicación Win32 válida
