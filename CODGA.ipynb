# %%
## IMPORTS 
import evotoon
from data_classes import CatParam, IntParam, FloatParam


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns#

import random

# %%
## MAKE SEED
SEED = evotoon.make_seed(39)
separator = "--------------------------------------------------------"

# %%
## EXAMPLE WITH CodGA

# Env configuration
poblation_size = 10

# Parameter settings
float_params = [
	FloatParam("p_c", 0.0001, 1, 4),
	FloatParam("p_m", 0.0001, 1, 4),
]
int_params = [
	IntParam("N", 1, 50),
]
cat_params = [
	CatParam("c_0", [1, 2]),
]


all_params = float_params + int_params + cat_params
all_params = {param.name: param for param in all_params}



initial_batch = evotoon.initialization(poblation_size, float_params, int_params, cat_params)

# Tuner parameters

update_cycle = 5
budget = 5000

# SET ENVIRONMENT FOR THE ACO ALGORITHM TO TUNE
path = "./InstanciasNKLandscapes/Instances-Testing"
n = 1

instance_list = evotoon.choose_instances(path, n , SEED)
instance_list, seed_list = evotoon.select_seeds(instance_list, 3, SEED)
print(separator, "Instances running and seeds", separator)
for ins,seed in zip(instance_list,seed_list):
	print("instance:", ins, "seed:", seed)

function_kwargs = {
	"executable_path": "./CodGA/ga-nk",
	"instance_list": instance_list,
	"seed_list": seed_list,
	"output": "xd.txt",
	"t_max": 100000 
}

print(pd.DataFrame(initial_batch))
# Out:
# -------------------------------------------------------- Instances running and seeds --------------------------------------------------------
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_20/nk_20_2.753 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_20/nk_20_2.753 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_20/nk_20_2.753 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_38/nk_38_2.262 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_38/nk_38_2.262 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_38/nk_38_2.262 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_52/nk_52_2.982 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_52/nk_52_2.982 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_2_52/nk_52_2.982 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_20/nk_20_3.85 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_20/nk_20_3.85 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_20/nk_20_3.85 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_34/nk_34_3.122 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_34/nk_34_3.122 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_34/nk_34_3.122 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_48/nk_48_3.37 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_48/nk_48_3.37 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_3_48/nk_48_3.37 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_20/nk_20_4.72 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_20/nk_20_4.72 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_20/nk_20_4.72 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_30/nk_30_4.911 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_30/nk_30_4.911 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_30/nk_30_4.911 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_40/nk_40_4.88 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_40/nk_40_4.88 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_4_40/nk_40_4.88 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_20/nk_20_5.166 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_20/nk_20_5.166 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_20/nk_20_5.166 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_28/nk_28_5.436 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_28/nk_28_5.436 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_28/nk_28_5.436 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_38/nk_38_5.105 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_38/nk_38_5.105 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_5_38/nk_38_5.105 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_20/nk_20_6.198 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_20/nk_20_6.198 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_20/nk_20_6.198 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_26/nk_26_6.49 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_26/nk_26_6.49 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_26/nk_26_6.49 seed: 41
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_32/nk_32_6.419 seed: 39
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_32/nk_32_6.419 seed: 40
# instance: ./InstanciasNKLandscapes/Instances-Testing/nk_6_32/nk_32_6.419 seed: 41
#       p_c     p_m   N  c_0
# 0  0.3122  0.2374  20    1
# 1  0.2821  0.5290  43    2
# 2  0.7471  0.9852  15    2
# 3  0.6464  0.4685  26    1
# 4  0.5525  0.7107  38    1
# 5  0.8632  0.1345  46    1
# 6  0.0547  0.3356   9    2
# 7  0.9925  0.0248  11    1
# 8  0.4602  0.6918   1    2
# 9  0.1798  0.8243  33    2

# %%
evotoon.evo_tunning(all_params=all_params, float_params=float_params, int_params=int_params, cat_params=cat_params, budget=budget, poblation_size=poblation_size, initial_batch=initial_batch, execute_algorithm=evotoon.execute_CodGA, returning_type="ABSOLUTE_OPTIMAL_DIFF", **function_kwargs)
# Out:
# Total Budget: 4550
# Budget left 4550
# Budget left 4100
# Budget left 3650
# Budget left 3200
# Budget left 2750
# Budget left 2300
# Budget left 1850
# Budget left 1400
# Budget left 950
# Budget left 500
# Budget left 50
#       p_c     p_m     N  c_0  Step_Found     VALUE
# 2  0.8139  0.4643  17.0  1.0           9  0.079800
# 6  0.8632  0.1345  46.0  2.0           4  0.099689
# 0  0.7232  0.2762  16.0  1.0           6  0.112823
# 1  0.7596  0.2374  20.0  1.0           4  0.115645
# 8  0.2924  0.6776  20.0  1.0          11  0.118245
# 4  0.7232  0.4685  16.0  1.0           1  0.129356
# 5  0.7956  0.1345  46.0  1.0          11  0.133066
# 3  0.8632  0.1345  46.0  1.0           0  0.139356
# 9  0.8632  0.1345  18.0  1.0           5  0.161333
# 7  0.4147  0.7335  36.0  1.0          11  0.171866
